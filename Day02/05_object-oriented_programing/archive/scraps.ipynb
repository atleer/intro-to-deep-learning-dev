# %% [markdown]
# Define an empty class named `MyClass`
# ```python
# class MyClass:
#     pass
# ```
#
# Define a class named `MyClass` that has a function named `myclass_function`.
#
# ```python
# class MyClass:
#     def myclass_function(self):
#         print("This is a function in MyClass")
# ```
#
# Create an instance of `Myclass`:
#
# ```python
# my_instance = MyClass()
# ```
#
# Call `MyClass`'s function `myclass_function`:
#
# ```python
# my_instance.myclass_function()
# ```
#
# Define a class named `MySubClass` that inherits from MyClass:
#
# ```python
# class SubClass(MyClass):
#     pass
# ```
#
# Create an instance of `SubClass` and call the function `myclass_function`, which is inherited from `MyClass`:
#
# ```python
# my_new_instance = SubClass()
#
# my_new_instance.myclass_function()
# ```

# %% [markdown]
# **Example**: Create a class named `Greet` with a function named `get_greeting` that prints "Hello" when called. Call the function from the class to check that it works.

# %%
class Greet:
    def get_greeting(self):
        print('Hello!')

Greet().get_greeting()
# Out:
# Hello!

# %% [markdown]
# **Exercise**: Create a class named `GermanGreet` with a function named `get_greeting` that prints "Hallo" when called. Call the function from the class to check that it works.

# %%
class GermanGreet:
    def get_greeting(self):
        print('Hallo!')

GermanGreet().get_greeting()
# Out:
# Hallo!

# %% [markdown]
# **Exercise**: Modify the function `get_greeting` in the class `GermanGreet` so that

# %% [markdown]
# **Exercise**: Create a class named `SubtractionSubclass` which **inherits** from the class named `Subtraction` and has a function named `log`. The `log` function prints the ....

# %%
class SubtractionSubClass(Subtraction):
    def __init__(self):
        self.a = 10
        self.b = 2

    def subtract_two_numbers(self):
        return super().subtract_two_numbers(self.a, self.b)
    

SubtractionSubClass().subtract_two_numbers()
# Out:
# 8

# %%
class MyClass:
    def myclass_function(self):
        print("This is a function in MyClass")

class MySubClass(MyClass):
    pass

b = MySubClass()
b.myclass_function()
# Out:
# This is a function in MyClass

# %% [markdown]
# **Exercise**: Add a function named `subtract_two_numbers` that takes the arguments `a` and `b` (in addition to `self`). The function should return the result of `a-b` when called. Call the function from the class and pass `a = 10` and `b = 2` to the function to check that it returns `8`.

# %%
class Math:
    def three_plus_two(self):
        return 3+2
    
    def subtract_two_numbers(self, a, b):
        return a-b
    
Math().subtract_two_numbers(10, 2)

# %%
class A:
    pass

# %%
class A:

    def arbitrary(self, new) -> int:
        print('override me!')
        return 3


def run(x: A):
    return x.arbitrary(1) * 2



class B(A):

    # Where to store your data
    def __init__(self): 
        self.stored = 3


    # function that can run on stored and new data
    def arbitrary(self, new): 
        return self.stored + new
    



b = B()
b.arbitrary(4)
run(b)
# Out:
# 8

# %% [markdown]
# ## Section 3: Leverage PyTorch's `nn.Module` to Make Your Own Neural Network Models
#
# | Code | Description |
# | :-- | :-- |
# | `class Model(nn.Module)` | Define class named `Model` that   |
