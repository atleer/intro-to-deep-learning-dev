# %% [markdown]
# ## Section: Functions Have Expectation on their Inputs.  Type Annotations can communicatie this intent

# %% [markdown]
# What is the motivation for this session? What questions does it answer?
#
# - How can we make it easier to work with models?
#   - Through good interfacing.
# - How do we make a good interface in general?
#   - Through OOP and type annotation.
# - How do we make an interface for deep learning?
#   - By leveraging PyTorch's neural network (nn) module
#     - Without it, you'd have to track parameters for each layer manually instead of getting all parameters together with `model.parameters()` - e.g, for optimizers, you can write `optimizer = torch.optim.Adam(model.parameters())` instead of `optimizer = torch.optim.Adam(list(layer1.parameters())+list(layer2.parameters()+...etc))`
#     - Switching device (model.to(device='cpu') or model.to(device='cuda')) much easier.
#     - (Maybe less important, but you get a printing of the model with all its layers.)
#   - Through encapsulation.

# %%
import torch
import torch.nn as nn

import numpy as np

# %% [markdown]
# ## Section 1: Models Expect a Certain Input. Type Annotations Can Communicate This Expectation to The User
#
# | Code | Description |
# | :-- | :-- |
# | `x: int` | `x` is an integer. |
# | `x: int = 5` | `x` is an integer with the value 5. |
# | `x: str` | `x` is a string. |
# | `x: float` | `x` is a float. |
# | `x: bool` | `x` is a boolean. |
# | `x: list` | `x` is a list. |
# | `x: list[float]` | `x` is a list containing elements that are floats. |
# | `x: torch.Tensor` | `x` is a tensor. |
# | `def fun(x: int)` | The argument `x` in `fun` is an integer. |
# | `def fun(x: list)` | The argument `x` in `fun` is a list. |
# | `def fun(x: np.ndarray)` | The argument `x` in `fun` is a numpy array. |
# | `def fun() -> torch.Tensor:` | The output of the function `fun` is a tensor. |
# | `def fun(x: np.ndarray) -> torch.Tensor:` | The argument `x` is a float and the is a tensor. |
#
# #### **Exercises**

# %% [markdown]
# **Example**: Annotate a variable `x` as an integer. As displayed in the screenshot below, when you type "`x`" after adding the type annotation, a hint should pop up saying that this variable is an integer. Check that you get this hint.

# %%
x: int

# %% [markdown]
# What the type hint should look like when you type "`x`":
#
# ![](img/type_hint_int.png)

# %% [markdown]
# **Exercise**: Annotate a variable `y` as an str. Check that the hint now says that `y` is a string.

# %%
y: str

# %% [markdown]
# What the type hint should look like when you type "`y`":
#
# ![](img/type_hint_str.png)

# %% [markdown]
# **Exercise**: Annotate a variable `z` as a list. Check that the hint now says that `z` is a list.

# %%
z: list

# %% [markdown]
# **Example**: Create and modify the function `two_times` below such that the argument `a` is annotated as an integer. Check that you get the right type hint when you write `two_times()` in a code cell. The screenshots below show what the type hints look like with and without annotation.
#
# ```python
# def two_times(a):
#     return 2*a
# ```

# %%
def two_times(a: int):
    return 2*a

# %% [markdown]
# What the hint will look like for an equivalent function **without** type annotation. Note that it says the type of the argument `a` is unknown.
#
# ![](img/two_times_wo_annotation.png)
#
# What the hint will look like for the function **with** type annotation:
#
# ![](img/two_times.png)

# %% [markdown]
# **Exercise**: Create and annotate the function `reverse_list` in the cell below such that the argument `b` is annotated as a list with elements that are strings. Check that you get the right type hint when you write `reverse_list` in a code cell.
#
# ```python
# def reverse_list(b): -> torch.Tensor
#     return g[::-1]
# ```

# %%
def reverse_list(b: list[str]):
    return b[::-1]

# %% [markdown]
# **Exercise**: Create and modify the function `make_tensor` such that the argument `c` is annotated as an array and the output is annotated as a Tensor. Check that you get the right type hint when you write `make_tensor()` in a code cell.
#
# ```python
# def make_tensor(c):
#     return torch.Tensor(c)
# ```

# %%
def make_tensor(c: np.ndarray) -> torch.Tensor:
    return torch.Tensor(c)

# %% [markdown]
# ## Section 2: Customizing Your Python Classes using Inhertiance in Python
#
# | Code | Description |
# | :-- | :-- |
# | `class MyClass:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`some_attribute = some_value` | Define a class named `MyClass` which has an attribute `some_attribute` with a value `some_value`. |
# | `class MyClass:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`def myclass_function(self):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`print("A function in MyClass")` | Define a class named `MyClass` that has a function named `myclass_function`. |
# | `class MyClass:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`def add_two_numbers(self, a, b):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`return a + b` | Define a class named `MyClass` that has a function named `add_two_numbers` which returns the sum of the arguments `a` and `b`. |
# | `MyClass().some_attribute` | Access the attribute named `some_attribute` from `MyClass`. |
# | `MyClass().myclass_function()` | Call `MyClass`'s function `myclass_function` |
# | `my_instance = MyClass()` | Create an instance of `MyClass` |
# | `my_instance.myclass_function()` | Call `MyClass`'s function `myclass_function` from the instance. |
# | `class SubClass(MyClass):`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...` | Define a class named `MySubClass` that inherits from MyClass |
# | `my_new_instance = SubClass()`<br>`my_new_instance.myclass_function()` | Create an instance of `SubClass` and call the function `myclass_function`, which is inherited from `MyClass` |
# | `class MyClass:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`def __init__(self, a, b):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`self.a = a`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`self.b = b` | Define a class named `MyClass` with a function `__init__` that initializes the attributes `a` and `b`. |

# %% [markdown]
# We're creating an inventory of fruits at a grocery store.
#
# **Example**: Create a class named `Fruits` that has one attribute `num_apples = 10`. Access the attribute from the class to check that it returns `10`.

# %%
class Fruits:
    num_apples = 10

Fruits().num_apples
# Out:
# 10

# %% [markdown]
# **Exercise**: Create a class named `Vegetables` that has one attribute `num_carrots = 20`. Access the attribute from the class to check that it returns `20`.

# %%
class Vegetables:
    num_carrots = 20

Vegetables().num_carrots
# Out:
# 20

# %% [markdown]
# **Exercise**: Create a class named `PerishedFruits` that has one attribute `num_apples = 10` and another attribute `num_bad_apples = 2`. Access the attribute `num_bad_apples` from the class to check that it returns `2`.

# %%
class PerishedFruits:
    num_apples = 10
    num_bad_apples = 2

PerishedFruits().num_bad_apples
# Out:
# 2

# %% [markdown]
# Instead of creating a new class that contains both `num_apples` and `num_bad_apples`, we can exploit that we already have a class `Fruits` that has the attribute `num_apples` and inherit from it. That reduces unecessary repetition and the amount of code we have to write.
#
# **Exercise**: Create a class named `Perished` that inherits from `Fruits` has one attribute `num_bad_apples = 10`. Access the attribute `num_apples` from the class to check that it returns `10`.

# %%
class Perished(Fruits):
    num_bad_apples = 1

Perished().num_apples
# Out:
# 10

# %% [markdown]
# **Exercise**: Create a class named `Expired` that inherits from the class `DairyProducts` provided below and has two attributes `num_bad_milk_cartons = 1` and `num_bad_yoghurts = 0`. Access the attribute `num_yoghurts` from the class to check that it returns `15`.

# %%
class DairyProducts:
    num_milk_cartons = 40
    num_yoghurts = 15

# %%
class Expired(DairyProducts):
    num_bad_milk_cartons = 1
    num_bad_yoghurts = 0

# %% [markdown]
# **Exercise**: Create an instance of `Expired` called `aldi_expired`. Access the `num_bad_milk_cartons` attribute **from the instance** to check that it returns `1`.

# %%
aldi_bonn = Expired()
aldi_bonn.num_bad_milk_cartons
# Out:
# 1

# %% [markdown]
# **Exercise**: Create an instance of `Expired` called `lidl_expired`. Access the `num_milk_cartons` attribute **from the instance** to check that it returns `40`.

# %%
aldi_aachen = Expired()
aldi_bonn.num_milk_cartons
# Out:
# 40

# %% [markdown]
# The way the `DairyProducts` and `Expired` classes are defined now, different instantiations of the classes will always have the same number of milk cartons and yoghurts. But of course, different stores usually have different numbers. To make it possible to create instances with different values for the attributes, we need to define the class with an `__init__`  function.
#
# **Example**: Create a new class named `DairyProducts` with an `__init__` function that initializes the attributes `num_milk_cartons` and `num_yoghurts`. Create one instance `aldi_berlin` with `num_milk_cartons = 100` and `num_yoghurts = 80` and another instance `aldi_hamburg` with `num_milk_cartons = 200` and `num_yoghurts = 45`

# %%
class DairyProducts:
    def __init__(self, num_milk_cartons: int, num_yoghurts: int):
        self.num_milk_cartons = num_milk_cartons
        self.num_yoghurts = num_yoghurts

aldi_berlin = DairyProducts(num_milk_cartons=100, num_yoghurts=80)
aldi_hamburg = DairyProducts(num_milk_cartons=200, num_yoghurts=45)

# %% [markdown]
# **Exercise**: Create a new class named `Fruits` with an `__init__` function that initializes the attribute `num_apples`. Create one instance `fruit_vendor_berlin` with `num_apples = 30` and another instance `fruit_vendor_hamburg` with `num_apples = 25`.

# %%
class Fruits:
    def __init__(self, num_apples: int):
        self.num_apples = num_apples

fruit_vendor_berlin = Fruits(num_apples=25)
fruit_vendor_hamburg = Fruits(num_apples=25)

# %% [markdown]
# **Demo/Extra Challenge**: Create a new class named `Perished` that inherits from `Vegetables` created below. It should have an `__init__` function that initializes the parent `Vegetables` that it inherits from and has an attribute `num_bad_carrots`. Create an instance `vegetable_vendor_bremen` with `num_bad_carrots = 2` and access the attribute `num_carrots` from it.

# %%
class Vegetables:
    def __init__(self, num_carrots: int = 5):
        self.num_carrots = num_carrots

# %%
class Perished(Vegetables):
    def __init__(self, num_bad_carrots: int):
        super().__init__()
        self.num_bad_carrots = num_bad_carrots

vegetable_vendor_bremen = Perished(num_bad_carrots=2)
vegetable_vendor_bremen.num_carrots
# Out:
# 5

# %% [markdown]
# ## Section 3: Make Your Own Neural Network Models using PyTorch's `nn.Module`.
#
# Make model that match requirements of interface - e.g. the optimizer.
#
# | Code | Description |
# | :-- | :-- |
# | `class Model(nn.Module)`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...` | Define class named `Model` that inherits from `nn.Module`. |
# | `class Model(nn.Module)`<br>&nbsp;&nbsp;&nbsp;&nbsp;`def __init__(self):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `super().__init__()` | Define class named `Model` that inherits from `nn.Module`.<br>`super().__init__()` initilizes the parent `nn.Module`. |
# | `class Model(nn.Module)`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`def __init__(self):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `super().__init__()` <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `self.layer = nn.Linear(2,2)` | Add a single layer 2 input and 2 output features to the model. |
# | `class Model(nn.Module)`<br>&nbsp;&nbsp;&nbsp;&nbsp;`def __init__(self):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `super().__init__()` <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `self.layer = nn.Linear(2,2)`<br><br>&nbsp;&nbsp;&nbsp;&nbsp;`def forward(self,x):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`return self.layer(x)` | Add a function `forward` to the model that carries out the forward pass of the input `x` through the network. |
# | `model.forward(x)` | Pass the input `x` to the model. |
# | `class Model(nn.Module)`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`def __init__(self, num_in, num_out):`<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `super().__init__()` <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `self.layer = nn.Linear(num_in,num_out)` | Add a single layer 2 input and 2 output features to the model. |
# | `optim.optimizer(model.parameters())` | Create an object that optimizes on the parameters (weights and biases) of `model`. |

# %% [markdown]
# **Example**: Create a class named `Model` that inherits from the `nn.Module` and is initialized with a two layers. The first layer has 1 input features and 8 output features. The second layer has 8 input features and 1 output feature. Display the model to make sure that it was created correctly.

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(1,8)
        self.layer2 = nn.Linear(8,1)
    
Model()
# Out:
# Model(
#   (layer1): Linear(in_features=1, out_features=8, bias=True)
#   (layer2): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# **Exercise**: Create a class named `Model` that inherits from the `nn.Module` and is initialized with a three layers. The first layer has 2 input features and 16 output features. The second layer has 16 input features and 16 output feature. The last layer has 16 input features and 1 output feature. Display the model to make sure that it was created correctly.

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(2,16),
        self.layer2 = nn.Linear(16,16),
        self.layer3 = nn.Linear(16,1)
    
Model()
# Out:
# Model(
#   (layer3): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
class Model:
    def __init__(self):
        super().__init__()
        self.layer = nn.Linear(11,1)
    
    def forward(self, x):
        out1 = self.layer(x)
        return out1

# Usage
x = torch.linspace(0, 10, 11)
model = Model()
result = model.forward(x)
result
# Out:
# tensor([-5.2077], grad_fn=<ViewBackward0>)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

# %%
df = pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')
X = torch.tensor(df.values[:, 1:], dtype=torch.float32)
y = torch.tensor(df.values[:, 0], dtype=torch.int32)
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
from torch.nn.modules import loss._Loss
from torch import tensor
from torch import TensorType
from typing import Type


# utility function
def train(X: TensorType, y: TensorType, model: nn.Module, loss_function = None):
    optimizer = optim.Adam(model.parameters())
    if loss_function is None:
        loss_function = nn.CrossEntropyLoss()
    

    losses = []
    for _ in tqdm(range(100), desc='Epoch'):
        optimizer.zero_grad()
        y_pred = model.forward(X)
        loss = loss_function(y_pred, y)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())

    return losses
# Out:
#   Cell In[24], line 1
#     from torch.nn.modules import loss._Loss
#                                      ^
# SyntaxError: invalid syntax

# %%
nn.NLLLoss.mro()
# Out:
# [torch.nn.modules.loss.NLLLoss,
#  torch.nn.modules.loss._WeightedLoss,
#  torch.nn.modules.loss._Loss,
#  torch.nn.modules.module.Module,
#  object]

# %%
model = nn.Module()
model.forward(X)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 model = nn.Module()
# ----> 2 model.forward(X)
#
# File c:\Users\delgr\Projects\new-learning-platform\intro-to-deep-learning-dev\.pixi\envs\default\Lib\site-packages\torch\nn\modules\module.py:387, in _forward_unimplemented(self, *input)
#     376 def _forward_unimplemented(self, *input: Any) -> None:
#     377     r"""Define the computation performed at every call.
#     378
#     379     Should be overridden by all subclasses.
#    (...)    385         registered hooks while the latter silently ignores them.
#     386     """
# --> 387     raise NotImplementedError(
#     388         f'Module [{type(self).__name__}] is missing the required "forward" function'
#     389     )
#
# NotImplementedError: Module [Module] is missing the required "forward" function

# %%
class MyModel(nn.Module):

    # Where to store models, variables, etc
    def __init__(self):
        super().__init__()
        self.model = nn.Linear(X.shape[1], 1)
        
    # Where to run the prediction
    def forward(self, X):
        return self.model(X)


model = MyModel()
model.forward(X)
# Out:
# tensor([[-217.6836],
#         [-217.6485],
#         [-246.7599],
#         [-309.7041],
#         [-146.2132],
#         [-303.4068],
#         [-270.5568],
#         [-269.1932],
#         [-216.1854],
#         [-215.9451],
#         [-317.7987],
#         [-268.4521],
#         [-277.7228],
#         [-239.6527],
#         [-325.5948],
#         [-272.7357],
#         [-265.2985],
#         [-232.7138],
#         [-354.0421],
#         [-170.6650],
#         [-155.0007],
#         [-156.0278],
#         [-214.4124],
#         [-210.6687],
#         [-173.1500],
#         [-166.6805],
#         [-250.0011],
#         [-270.0026],
#         [-186.9003],
#         [-214.5875],
#         [-268.4868],
#         [-318.5572],
#         [-203.8902],
#         [-254.4632],
#         [-226.3656],
#         [-188.7862],
#         [-178.8490],
#         [-229.7725],
#         [-211.2657],
#         [-150.6359],
#         [-159.0519],
#         [-215.5458],
#         [-226.9332],
# ...

# %% [markdown]
# ## Section 4
