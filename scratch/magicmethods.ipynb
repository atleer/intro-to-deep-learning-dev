# %%
class MyData:
    data = [10, 20, 30, 40]
    _idx = 0
    
    # def __iter__(self):
    #     self._idx = 0
    #     return self

    # def __next__(self):
    #     value = self.data[self._idx]
    #     self._idx += 1

    #     if self._idx >= len(self.data):
    #         raise StopIteration
        
    #     return value
    
    # def __len__(self):
    #     return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

for val in iter(MyData()):
    print(val)

# len(MyData())
MyData()[1]
# Out:
# 10
# 20
# 30
# 20
