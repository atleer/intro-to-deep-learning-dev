# %% [raw]
# +++
# weight = 2
# title = "Create Neural Networks"
# description = ""
#
# [[author]]
# name = "Dr. Atle E. Rimehaug"
# role = "Conceptualization, Writing, and Editing"
#
# [[author]]
# name = "Dr. Nicholas Del Grosso"
# role = "Conceptualization, Writing, and Editing"
# +++

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries

# %%
import torch
import torch.nn as nn

from sklearn.datasets import make_moons, load_iris
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get Data

# %%
X, y = make_moons(256, noise=0.1, random_state=42)
X= torch.from_numpy(X.astype('float32'))
y = 2 * torch.from_numpy(y.astype('int32'))


plt.scatter(*X.T, s = 20, c = y, cmap='Dark2');

# %%
# Something is not working here, beyond the model not being good.  
# Try with more steps, you'll see
# Answer: 
# 1) The decision border for y_pred shouldn't be at 0. y-values fall between 0 and 2 (2 because of multiplication by 2 above)
# 2) It's a classification problem, so an MSE loss function is not the most appropriate
# 3) It's a non-linear problem, so there's either way a limit to how well linear regression will perform

from torch import optim

torch.manual_seed(42)

model = nn.Linear(2, 1)  # linear regression

#optimizer = optim.RMSprop(model.parameters(), lr=0.1)  # Optimizer automatically updates parameters
optimizer = optim.Adam(model.parameters(), lr=0.2)

for step in range(100):
    y_pred = model(X)  # forward pass (prediction)
    loss = (y_pred - y).square().mean()  # error prediction (i.e. "loss")
    print(f"loss={loss:.4f}, weights={model.weight}")
    optimizer.zero_grad()  # 
    loss.backward()
    optimizer.step()



plt.scatter(*X.T, s = 20, c = y_pred > 1.0, cmap='Set1');
#plt.scatter(*X.T, s = 20, c = y_pred > 0.0, cmap='Set1');
# Out:
# loss=1.7390, weights=Parameter containing:
# tensor([[0.5406, 0.5869]], requires_grad=True)
# loss=1.5023, weights=Parameter containing:
# tensor([[0.7406, 0.7869]], requires_grad=True)
# loss=1.3524, weights=Parameter containing:
# tensor([[0.6437, 0.9594]], requires_grad=True)
# loss=1.2693, weights=Parameter containing:
# tensor([[0.5034, 1.0330]], requires_grad=True)
# loss=1.2132, weights=Parameter containing:
# tensor([[0.3509, 1.0035]], requires_grad=True)
# loss=1.1725, weights=Parameter containing:
# tensor([[0.2051, 0.9145]], requires_grad=True)
# loss=1.1409, weights=Parameter containing:
# tensor([[0.0855, 0.7919]], requires_grad=True)
# loss=1.1094, weights=Parameter containing:
# tensor([[0.0061, 0.6489]], requires_grad=True)
# loss=1.0746, weights=Parameter containing:
# tensor([[-0.0334,  0.4933]], requires_grad=True)
# loss=1.0419, weights=Parameter containing:
# tensor([[-0.0433,  0.3308]], requires_grad=True)
# loss=1.0182, weights=Parameter containing:
# tensor([[-0.0368,  0.1666]], requires_grad=True)
# loss=1.0073, weights=Parameter containing:
# tensor([[-0.0263,  0.0067]], requires_grad=True)
# loss=1.0085, weights=Parameter containing:
# tensor([[-0.0218, -0.1425]], requires_grad=True)
# loss=1.0181, weights=Parameter containing:
# tensor([[-0.0291, -0.2737]], requires_grad=True)
# loss=1.0317, weights=Parameter containing:
# tensor([[-0.0485, -0.3804]], requires_grad=True)
# loss=1.0451, weights=Parameter containing:
# tensor([[-0.0764, -0.4581]], requires_grad=True)
# loss=1.0551, weights=Parameter containing:
# tensor([[-0.1066, -0.5056]], requires_grad=True)
# loss=1.0594, weights=Parameter containing:
# tensor([[-0.1329, -0.5244]], requires_grad=True)
# loss=1.0574, weights=Parameter containing:
# tensor([[-0.1504, -0.5182]], requires_grad=True)
# loss=1.0507, weights=Parameter containing:
# tensor([[-0.1570, -0.4914]], requires_grad=True)
# loss=1.0425, weights=Parameter containing:
# tensor([[-0.1542, -0.4489]], requires_grad=True)
# loss=1.0355, weights=Parameter containing:
# tensor([[-0.1453, -0.3957]], requires_grad=True)
# loss=1.0308, weights=Parameter containing:
# tensor([[-0.1347, -0.3362]], requires_grad=True)
# loss=1.0272, weights=Parameter containing:
# tensor([[-0.1255, -0.2747]], requires_grad=True)
# loss=1.0236, weights=Parameter containing:
# tensor([[-0.1192, -0.2148]], requires_grad=True)
# loss=1.0191, weights=Parameter containing:
# tensor([[-0.1146, -0.1594]], requires_grad=True)
# loss=1.0142, weights=Parameter containing:
# tensor([[-0.1085, -0.1104]], requires_grad=True)
# loss=1.0094, weights=Parameter containing:
# tensor([[-0.0973, -0.0685]], requires_grad=True)
# loss=1.0052, weights=Parameter containing:
# tensor([[-0.0782, -0.0337]], requires_grad=True)
# loss=1.0021, weights=Parameter containing:
# tensor([[-0.0505, -0.0052]], requires_grad=True)
# loss=1.0004, weights=Parameter containing:
# tensor([[-0.0163,  0.0182]], requires_grad=True)
# loss=1.0007, weights=Parameter containing:
# tensor([[0.0202, 0.0382]], requires_grad=True)
# loss=1.0026, weights=Parameter containing:
# tensor([[0.0539, 0.0561]], requires_grad=True)
# loss=1.0052, weights=Parameter containing:
# tensor([[0.0796, 0.0732]], requires_grad=True)
# loss=1.0073, weights=Parameter containing:
# tensor([[0.0941, 0.0900]], requires_grad=True)
# loss=1.0082, weights=Parameter containing:
# tensor([[0.0971, 0.1067]], requires_grad=True)
# loss=1.0082, weights=Parameter containing:
# tensor([[0.0905, 0.1228]], requires_grad=True)
# loss=1.0077, weights=Parameter containing:
# tensor([[0.0783, 0.1373]], requires_grad=True)
# loss=1.0069, weights=Parameter containing:
# tensor([[0.0646, 0.1489]], requires_grad=True)
# loss=1.0062, weights=Parameter containing:
# tensor([[0.0526, 0.1562]], requires_grad=True)
# loss=1.0055, weights=Parameter containing:
# tensor([[0.0441, 0.1580]], requires_grad=True)
# loss=1.0048, weights=Parameter containing:
# tensor([[0.0386, 0.1534]], requires_grad=True)
# loss=1.0042, weights=Parameter containing:
# tensor([[0.0345, 0.1420]], requires_grad=True)
# loss=1.0035, weights=Parameter containing:
# tensor([[0.0298, 0.1242]], requires_grad=True)
# loss=1.0025, weights=Parameter containing:
# tensor([[0.0233, 0.1009]], requires_grad=True)
# loss=1.0013, weights=Parameter containing:
# tensor([[0.0149, 0.0735]], requires_grad=True)
# loss=1.0005, weights=Parameter containing:
# tensor([[0.0058, 0.0438]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0022,  0.0139]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0076, -0.0141]], requires_grad=True)
# loss=1.0005, weights=Parameter containing:
# tensor([[-0.0099, -0.0385]], requires_grad=True)
# loss=1.0008, weights=Parameter containing:
# tensor([[-0.0098, -0.0579]], requires_grad=True)
# loss=1.0012, weights=Parameter containing:
# tensor([[-0.0091, -0.0716]], requires_grad=True)
# loss=1.0014, weights=Parameter containing:
# tensor([[-0.0097, -0.0792]], requires_grad=True)
# loss=1.0014, weights=Parameter containing:
# tensor([[-0.0128, -0.0812]], requires_grad=True)
# loss=1.0013, weights=Parameter containing:
# tensor([[-0.0184, -0.0783]], requires_grad=True)
# loss=1.0012, weights=Parameter containing:
# tensor([[-0.0253, -0.0719]], requires_grad=True)
# loss=1.0011, weights=Parameter containing:
# tensor([[-0.0314, -0.0631]], requires_grad=True)
# loss=1.0011, weights=Parameter containing:
# tensor([[-0.0345, -0.0532]], requires_grad=True)
# loss=1.0010, weights=Parameter containing:
# tensor([[-0.0337, -0.0433]], requires_grad=True)
# loss=1.0008, weights=Parameter containing:
# tensor([[-0.0289, -0.0340]], requires_grad=True)
# loss=1.0005, weights=Parameter containing:
# tensor([[-0.0215, -0.0259]], requires_grad=True)
# loss=1.0003, weights=Parameter containing:
# tensor([[-0.0132, -0.0189]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0058, -0.0128]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-7.7886e-05, -7.3801e-03]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[ 0.0039, -0.0021]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[0.0067, 0.0032]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0092, 0.0089]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0117, 0.0147]], requires_grad=True)
# loss=1.0003, weights=Parameter containing:
# tensor([[0.0141, 0.0205]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0156, 0.0259]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0155, 0.0302]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0138, 0.0330]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0107, 0.0339]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0071, 0.0327]], requires_grad=True)
# loss=1.0002, weights=Parameter containing:
# tensor([[0.0042, 0.0294]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[0.0026, 0.0243]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[0.0024, 0.0180]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0030, 0.0109]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0035, 0.0038]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[ 0.0032, -0.0026]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[ 0.0017, -0.0080]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0005, -0.0120]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0030, -0.0144]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0049, -0.0154]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0060, -0.0153]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0063, -0.0142]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0062, -0.0127]], requires_grad=True)
# loss=1.0001, weights=Parameter containing:
# tensor([[-0.0060, -0.0110]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0059, -0.0094]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0056, -0.0078]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0049, -0.0065]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0036, -0.0052]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[-0.0017, -0.0039]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[ 0.0003, -0.0025]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[ 0.0021, -0.0008]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0031, 0.0010]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0034, 0.0029]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0030, 0.0048]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0024, 0.0064]], requires_grad=True)
# loss=1.0000, weights=Parameter containing:
# tensor([[0.0020, 0.0076]], requires_grad=True)

# %% [markdown]
# ## Section 2: Fit with a Neural Network Model
#
# | Code | Description |
# | --- | --- |
# | `nn.Linear(n_features_in, n_features_out)` | Creates a single layer of neurons that takes in `n_features_in` input features and outputs `n_features_out` features.|
# | `nn.ReLU()` | Creates a rectified linear unit activation function.|
# | `nn.Tanh()` | Creates a hyperbolic tangent activation function.|
# | `nn.Softmax()` | Creates a softmax activation function.|
# | `nn.Sequential(`<br>&nbsp;&nbsp;&nbsp;&nbsp;`nn.Linear(1,10),`<br>&nbsp;&nbsp;&nbsp;&nbsp;` nn.ReLU(),`<br>&nbsp;&nbsp;&nbsp;` nn.Linear(10,1)`<br>`)` | Creates a container where layers and activation functions are stacked in a sequential order. This ensures that the input is passed through the network in that order.|

# %% [markdown]
# ## Section 3: The Loss Function
#
# | Code | Description |
# | --- | --- |
# | `net(X_input)` | Pass input `X_input` to a neuronal network `net`. |
# | `y_net = net(X_input)` | Pass input `X_input` to a neuronal network `net` and assign the output to a variable `y_net`. |
# | `loss_function = nn.MSELoss()` | Creates a mean squared error (MSE) loss function and assigns it to a variable named `loss_function`. Typically used for regression problems. |
# | `nn.CrossEntropyLoss()` | Creates a cross-entropy loss function. Used for classification problems.|
# | `nn.NLLLoss()` | Creates a negative log-likelihood loss function. Used for classification problems. Expects different input format than cross-entropy loss. |
# | `loss_function = nn.CrossEntropyLoss()` | Creates a cross-entropy loss function and assigns it to a variable named `loss_function`. Typically used for regression problems. |
# | `loss_function(y_net, y_true)` | Calculates the loss between the output of the network `y_net` and the true y-values from the data `y_true`. |
# | `loss_function(y_net, y_true).item()` | Extracts the loss value (the number alone as a ``float`` and not as a ``tensor`` type). |

# %% [markdown]
# **Example**: Pass the input ``X_samples``  to the network `net` defined below. When you display the output from the network it should look something like this:
#
# **TODO: Update numbers**
#
# tensor([[-0.0750, -0.1321],  <br>
# &nbsp;[-0.6765,  0.0395],  <br>
# &nbsp;[-0.3084, -0.0583],  <br>
# &nbsp;[-0.0244,  0.0879],  <br>
# &nbsp;[-0.2079, -0.0272]], grad_fn=``<AddmmBackward0>``)

# %%
# provided

# set seed for reproducibility
seed = 42
torch.manual_seed(seed)

# select subset of data
X_samples = X[:5]

# define network
net = nn.Sequential(
    nn.Linear(2,16),
    nn.ReLU(),
    nn.Linear(16, 2)
)

# %%
net(X_samples)
# Out:
# tensor([[ 0.2759,  0.3435],
#         [ 0.1586,  0.0792],
#         [-0.2391, -0.6694],
#         [ 0.1299,  0.2777],
#         [-0.3268, -0.8778]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Exercise**: Create a network that is a sequence of two layers with a rectified linear unit between them and pass the input ``X_samples`` to the network. The net should have 2 input features and 10 output features in the first layer, 10 input features and 2 output features in the last layer, and a rectified linear unit between them.
#
# **TODO: Update numbers**
#
# When you display the output from the network it should look something like this:
#
# tensor([[-0.7792,  0.3448], <br>
# &nbsp;[-1.1195,  0.5286],  <br>
# &nbsp;[-0.9589,  0.4255],  <br>
# &nbsp;[-0.7205,  0.2652],  <br>
# &nbsp;[-0.9274,  0.4547]], grad_fn=``<AddmmBackward0>``)
#
# *Note*: If you get different numbers, it might be because you haven't set the seed before creating the network (see code provided in previous exercise).

# %%
# set seed for reproducibility
seed = 42
torch.manual_seed(seed)

net = nn.Sequential(
    nn.Linear(2,10),
    nn.ReLU(),
    nn.Linear(10, 2)
)

net(X_samples)
# Out:
# tensor([[ 0.0641,  0.2361],
#         [-0.0886,  0.0924],
#         [-0.3893,  0.1175],
#         [-0.1926,  0.1436],
#         [-0.3431,  0.1260]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Exercise**: Create a network that is a sequence of *three* layers with a *hyperbolic tangent activation function* between each layer and pass the input ``X_samples`` to the network. The net should have 2 input features in the first layer, and 32 output features in the first layer, 32 input features and 32 output features in the second layer, and 32 input features and 2 output features in last layer.

# %%
net = nn.Sequential(
    nn.Linear(2,32),
    nn.Tanh(),
    nn.Linear(32, 32),
    nn.Tanh(),
    nn.Linear(32,2)
)

net(X_samples)
# Out:
# tensor([[-0.2211,  0.1321],
#         [-0.2285,  0.0786],
#         [-0.1711, -0.1686],
#         [-0.1933,  0.1706],
#         [-0.0594, -0.1528]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Example**: Create a negative log-likelihood loss function.

# %%
loss_function = nn.NLLLoss()
loss_function
# Out:
# NLLLoss()

# %% [markdown]
# **Exercise**: Create a mean square error loss function.

# %%
loss_function = nn.MSELoss()
loss_function
# Out:
# MSELoss()

# %% [markdown]
# **Exercise**: Create a cross entropy loss function.

# %%
loss_function = nn.CrossEntropyLoss()
loss_function
# Out:
# CrossEntropyLoss()

# %% [markdown]
# **Exercise**: Calculate the loss between the output `y_net` produced by the neural net in the cell below and the original y-data `y_true`.

# %%
# provided

# create net
net = nn.Sequential(
    nn.Linear(2,16),
    nn.ReLU(),
    nn.Linear(16,2)
)

# select subset of data
X_samples = X[:5]
y_true = y[:5]

# pass subset to network
y_net = net(X_samples)

# define loss function
loss_function = nn.CrossEntropyLoss()

# %%
loss_function(y_net, y_true)
# Out:
# tensor(0.7451, grad_fn=<NllLossBackward0>)

# %% [markdown]
# **Exercise**: Extract the value of the loss (the number alone).
#
# **Hint**: ``.item()``

# %%
loss_function(y_net, y_true).item()
# Out:
# 0.7450814247131348

# %% [markdown]
# **Exercise**: Assign the loss value to a variable named `loss`.

# %%
loss = loss_function(y_net, y_true).item()
loss
# Out:
# 0.7450814247131348

# %% [markdown]
# ## Sectoin 4: The Optimizer
#
# | Code | Description |
# | --- | --- |
# | `optim.SGD(net.parameters())` | Creates a stochastic gradient descent (GD) optimizer. |
# | `optim.SGD(net.parameters(), lr=0.01, momentum = 0.99)` | Creates a stochastic gradient descent (GD) optimizer with a learning rate `lr` of 0.01 (the default value is 0.001) and ``momentum`` of 0.99 (the default value is 0.9). |
# | `optim.Adagrad(net.parameters())` | Creates an adaptive gradient descent optimizer.|
# | `optim.ADAM(net.parameters())` | Creates an adaptive moment optimizer .|
# | `optimizer = optim.SGD(net.parameters())` | Creates a stochastic gradient descent (GD) optimizer and assigns it to a variable called `optimizer`. |

# %% [markdown]
# **Example**: Create a stochastic gradient descent optimizer for the parameters of the network `net`.

# %%
optimizer = torch.optim.SGD(net.parameters())
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %% [markdown]
# **Exercise**: Create an adaptive gradient (Adagrad) optimize.

# %%
optimizer = torch.optim.Adagrad(net.parameters())
optimizer
# Out:
# Adagrad (
# Parameter Group 0
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     initial_accumulator_value: 0
#     lr: 0.01
#     lr_decay: 0
#     maximize: False
#     weight_decay: 0
# )

# %% [markdown]
# **Exercise**: Create an adaptive moment (Adam) optimizer with learning rate ``lr = 0.01``.

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.01)
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )

# %% [markdown]
# **Exercise**: Create a gradient descent optimizer with `momentum = 0.95` and learning rate `lr = 0.01`.

# %%
optimizer = torch.optim.SGD(net.parameters(), lr = 0.01, momentum = 0.95)
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.95
#     nesterov: False
#     weight_decay: 0
# )
